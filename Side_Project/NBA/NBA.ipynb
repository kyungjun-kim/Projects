# %% [markdown]
# ### 데이터 불러오기

# %%
#!pip install nba_api
#!pip install tabulate
from tabulate import tabulate
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nba_api

# %%
encoding = "utf-8"
from nba_api.stats.static import players
#df = players.find_players_by_full_name("Russell Westbrook")
df = players.find_players_by_full_name("michael jordan")
#_first_name("russel")
print(df)
# Out:
# [{'id': 893, 'full_name': 'Michael Jordan', 'first_name': 'Michael', 'last_name': 'Jordan', 'is_active': False}]

# %%
from nba_api.stats.endpoints import commonplayerinfo

player_info = commonplayerinfo.CommonPlayerInfo(player_id=893)#)201566)
test = player_info.get_data_frames()
test[0].head()
#test[1].head()
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME  ... DRAFT_ROUND DRAFT_NUMBER GREATEST_75_FLAG
# 0        893    Michael    Jordan  ...           1            3                Y
#
# [1 rows x 33 columns]

# %%
from nba_api.stats.endpoints import playercareerstats

career = playercareerstats.PlayerCareerStats(player_id=893)#'201566')
temp = career.get_data_frames()
temp[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  ...  BLK  TOV   PF   PTS
# 0         893   1984-85        00  1610612741  ...   69  291  285  2313
# 1         893   1985-86        00  1610612741  ...   21   45   46   408
# 2         893   1986-87        00  1610612741  ...  125  272  237  3041
# 3         893   1987-88        00  1610612741  ...  131  252  270  2868
# 4         893   1988-89        00  1610612741  ...   65  290  247  2633
# 5         893   1989-90        00  1610612741  ...   54  247  241  2753
# 6         893   1990-91        00  1610612741  ...   83  202  229  2580
# 7         893   1991-92        00  1610612741  ...   75  200  201  2404
# 8         893   1992-93        00  1610612741  ...   61  207  188  2541
# 9         893   1994-95        00  1610612741  ...   13   35   47   457
# 10        893   1995-96        00  1610612741  ...   42  197  195  2491
# 11        893   1996-97        00  1610612741  ...   44  166  156  2431
# ...

# %%
print(tabulate(temp[0], headers='keys', tablefmt='psql', showindex=True))
# Out:
# +----+-------------+-------------+-------------+------------+---------------------+--------------+------+------+-------+-------+-------+----------+--------+--------+-----------+-------+-------+----------+--------+--------+-------+-------+-------+-------+-------+------+-------+
# |    |   PLAYER_ID | SEASON_ID   |   LEAGUE_ID |    TEAM_ID | TEAM_ABBREVIATION   |   PLAYER_AGE |   GP |   GS |   MIN |   FGM |   FGA |   FG_PCT |   FG3M |   FG3A |   FG3_PCT |   FTM |   FTA |   FT_PCT |   OREB |   DREB |   REB |   AST |   STL |   BLK |   TOV |   PF |   PTS |
# |----+-------------+-------------+-------------+------------+---------------------+--------------+------+------+-------+-------+-------+----------+--------+--------+-----------+-------+-------+----------+--------+--------+-------+-------+-------+-------+-------+------+-------|
# ...

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

# dictionary
games.get_dict()
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2023-04-24 01:45:32.4532',
#   'code': 200},
#  'scoreboard': {'gameDate': '2023-04-23',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0042200134',
#     'gameCode': '20230423/CLENYK',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-04-23T17:00:00Z',
#     'gameEt': '2023-04-23T13:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': 'Game 4',
#     'seriesText': 'NYK leads 3-1',
#     'seriesConference': 'East',
#     'poRoundDesc': 'First Round',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612752,
#      'teamName': 'Knicks',
#      'teamCity': 'New York',
#      'teamTricode': 'NYK',
#      'wins': 3,
#      'losses': 1,
# ...
