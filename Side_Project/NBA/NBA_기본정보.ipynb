# %% [markdown]
# ## 라이브러리 설치

# %%
# !pip install nba_api
from pyspark.sql import SparkSession, SQLContext, Row, SparkSession

encoding = 'utf-8'
# Out:
# Collecting nba_api
#   Downloading nba_api-1.4.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in /opt/conda/lib/python3.11/site-packages (from nba_api) (2023.7.22)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /opt/conda/lib/python3.11/site-packages (from nba_api) (1.24.4)
# Requirement already satisfied: requests<3.0,>=2.31 in /opt/conda/lib/python3.11/site-packages (from nba_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.31->nba_api) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.31->nba_api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.31->nba_api) (2.0.7)
# Downloading nba_api-1.4.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: nba_api
# Successfully installed nba_api-1.4.1

# %% [markdown]
# ## 선수 정보 확인

# %% [markdown]
# ### 기본 정보 확인
# - 르브론 제임스의 정보 확인

# %%
#from nba_api.stats.static import players

p_profile = players.find_players_by_full_name("Lebron James")
print(p_profile[0])
p_id = p_profile[0]['id']
# Out:
# {'id': 2544, 'full_name': 'LeBron James', 'first_name': 'LeBron', 'last_name': 'James', 'is_active': True}

# %% [markdown]
# ### 선수의 상세 정보 확인
# - 위 코드에서 알게된 선수 ID를 이용해서 상세 정보를 확인할 수 있다

# %%
from nba_api.stats.endpoints import commonplayerinfo

player_info = commonplayerinfo.CommonPlayerInfo(player_id=p_id)
p_info = player_info.get_data_frames()
print(p_info[0])
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2544     LeBron     James       LeBron James            James, LeBron
#
#   DISPLAY_FI_LAST   PLAYER_SLUG            BIRTHDATE  \
# 0        L. James  lebron-james  1984-12-30T00:00:00
#
#                          SCHOOL COUNTRY  ...    PLAYERCODE FROM_YEAR TO_YEAR  \
# 0  St. Vincent-St. Mary HS (OH)     USA  ...  lebron_james      2003    2023
#
#    DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND  \
# 0             N        Y                 Y       2003           1
#
#    DRAFT_NUMBER GREATEST_75_FLAG
# 0             1                Y
#
# [1 rows x 33 columns]

# %% [markdown]
# - 해당 코드는 선수의 정보를 list 형태로 보여준다. 리스트의 0번째 인덱스에는 이름, 키 몸무게, 출신학교 등 기본 프로필 정보를, 1번째 인덱스에는 경기 결과 통계정보를, 2번째 인덱스에는 출전했던 시즌의 id를 보여준다

# %% [markdown]
# ### 경기 기록 정보 확인

# %%
from nba_api.stats.endpoints import playercareerstats

career = playercareerstats.PlayerCareerStats(player_id = p_id)
career_info = career.get_data_frames()
print(career_info[0])
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# 11       2544   2014-15        00  1610612739               CLE        30.0
# 12       2544   2015-16        00  1610612739               CLE        31.0
# 13       2544   2016-17        00  1610612739               CLE        32.0
# 14       2544   2017-18        00  1610612739               CLE        33.0
# 15       2544   2018-19        00  1610612747               LAL        34.0
# 16       2544   2019-20        00  1610612747               LAL        35.0
# 17       2544   2020-21        00  1610612747               LAL        36.0
# 18       2544   2021-22        00  1610612747               LAL        37.0
# 19       2544   2022-23        00  1610612747               LAL        38.0
# 20       2544   2023-24        00  1610612747               LAL        39.0
#
#     GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0   79  79  3120.0  622  ...   0.754    99   333  432  465  130   58  273
# 1   80  80  3388.0  795  ...   0.750   111   477  588  577  177   52  262
# 2   79  79  3361.0  875  ...   0.738    75   481  556  521  123   66  260
# 3   78  78  3190.0  772  ...   0.698    83   443  526  470  125   55  250
# 4   75  74  3027.0  794  ...   0.712   133   459  592  539  138   81  255
# 5   81  81  3054.0  789  ...   0.780   106   507  613  587  137   93  241
# 6   76  76  2966.0  768  ...   0.767    71   483  554  651  125   77  261
# 7   79  79  3063.0  758  ...   0.759    80   510  590  554  124   50  284
# 8   62  62  2326.0  621  ...   0.771    94   398  492  387  115   50  213
# 9   76  76  2877.0  765  ...   0.753    97   513  610  551  129   67  226
# 10  77  77  2902.0  767  ...   0.750    81   452  533  488  121   26  270
# 11  69  69  2493.0  624  ...   0.710    51   365  416  511  109   49  272
# 12  76  76  2709.0  737  ...   0.731   111   454  565  514  104   49  249
# 13  74  74  2795.0  736  ...   0.674    97   542  639  646   92   44  303
# 14  82  82  3026.0  857  ...   0.731    97   612  709  747  116   71  347
# 15  55  55  1937.0  558  ...   0.665    57   408  465  454   72   33  197
# 16  67  67  2316.0  643  ...   0.693    66   459  525  684   78   36  261
# 17  45  45  1504.0  422  ...   0.698    29   317  346  350   48   25  168
# 18  56  56  2084.0  640  ...   0.756    63   396  459  349   73   59  196
# 19  55  54  1954.0  609  ...   0.768    65   392  457  375   50   32  178
# 20  58  58  2040.0  551  ...   0.741    48   368  416  466   73   33  189
#
#      PF   PTS
# 0   149  1654
# 1   146  2175
# 2   181  2478
# 3   171  2132
# 4   165  2250
# 5   139  2304
# 6   119  2258
# 7   163  2111
# 8    96  1683
# 9   110  2036
# 10  126  2089
# 11  135  1743
# 12  143  1920
# 13  134  1954
# 14  136  2251
# 15   94  1505
# 16  118  1698
# 17   70  1126
# 18  121  1695
# 19   88  1590
# 20   69  1462
#
# [21 rows x 27 columns]

# %%
from pyspark.sql import SparkSession

#Create PySpark SparkSession
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("NBA_data") \
    .getOrCreate()

#Create PySpark DataFrame from Pandas
sparkDF=spark.createDataFrame(career_info[0]) 
sparkDF.printSchema()
sparkDF.show()
# Out:
# root
#  |-- PLAYER_ID: long (nullable = true)
#  |-- SEASON_ID: string (nullable = true)
#  |-- LEAGUE_ID: string (nullable = true)
#  |-- TEAM_ID: long (nullable = true)
#  |-- TEAM_ABBREVIATION: string (nullable = true)
#  |-- PLAYER_AGE: double (nullable = true)
#  |-- GP: long (nullable = true)
#  |-- GS: long (nullable = true)
#  |-- MIN: double (nullable = true)
#  |-- FGM: long (nullable = true)
#  |-- FGA: long (nullable = true)
#  |-- FG_PCT: double (nullable = true)
#  |-- FG3M: long (nullable = true)
#  |-- FG3A: long (nullable = true)
#  |-- FG3_PCT: double (nullable = true)
#  |-- FTM: long (nullable = true)
#  |-- FTA: long (nullable = true)
#  |-- FT_PCT: double (nullable = true)
#  |-- OREB: long (nullable = true)
#  |-- DREB: long (nullable = true)
#  |-- REB: long (nullable = true)
#  |-- AST: long (nullable = true)
#  |-- STL: long (nullable = true)
#  |-- BLK: long (nullable = true)
#  |-- TOV: long (nullable = true)
#  |-- PF: long (nullable = true)
#  |-- PTS: long (nullable = true)
#
# +---------+---------+---------+----------+-----------------+----------+---+---+------+---+----+------+----+----+-------+---+---+------+----+----+---+---+---+---+---+---+----+
# |PLAYER_ID|SEASON_ID|LEAGUE_ID|   TEAM_ID|TEAM_ABBREVIATION|PLAYER_AGE| GP| GS|   MIN|FGM| FGA|FG_PCT|FG3M|FG3A|FG3_PCT|FTM|FTA|FT_PCT|OREB|DREB|REB|AST|STL|BLK|TOV| PF| PTS|
# +---------+---------+---------+----------+-----------------+----------+---+---+------+---+----+------+----+----+-------+---+---+------+----+----+---+---+---+---+---+---+----+
# |     2544|  2003-04|       00|1610612739|              CLE|      19.0| 79| 79|3120.0|622|1492| 0.417|  63| 217|   0.29|347|460| 0.754|  99| 333|432|465|130| 58|273|149|1654|
# |     2544|  2004-05|       00|1610612739|              CLE|      20.0| 80| 80|3388.0|795|1684| 0.472| 108| 308|  0.351|477|636|  0.75| 111| 477|588|577|177| 52|262|146|2175|
# |     2544|  2005-06|       00|1610612739|              CLE|      21.0| 79| 79|3361.0|875|1823|  0.48| 127| 379|  0.335|601|814| 0.738|  75| 481|556|521|123| 66|260|181|2478|
# |     2544|  2006-07|       00|1610612739|              CLE|      22.0| 78| 78|3190.0|772|1621| 0.476|  99| 310|  0.319|489|701| 0.698|  83| 443|526|470|125| 55|250|171|2132|
# |     2544|  2007-08|       00|1610612739|              CLE|      23.0| 75| 74|3027.0|794|1642| 0.484| 113| 359|  0.315|549|771| 0.712| 133| 459|592|539|138| 81|255|165|2250|
# |     2544|  2008-09|       00|1610612739|              CLE|      24.0| 81| 81|3054.0|789|1613| 0.489| 132| 384|  0.344|594|762|  0.78| 106| 507|613|587|137| 93|241|139|2304|
# |     2544|  2009-10|       00|1610612739|              CLE|      25.0| 76| 76|2966.0|768|1528| 0.503| 129| 387|  0.333|593|773| 0.767|  71| 483|554|651|125| 77|261|119|2258|
# |     2544|  2010-11|       00|1610612748|              MIA|      26.0| 79| 79|3063.0|758|1485|  0.51|  92| 279|   0.33|503|663| 0.759|  80| 510|590|554|124| 50|284|163|2111|
# |     2544|  2011-12|       00|1610612748|              MIA|      27.0| 62| 62|2326.0|621|1169| 0.531|  54| 149|  0.362|387|502| 0.771|  94| 398|492|387|115| 50|213| 96|1683|
# |     2544|  2012-13|       00|1610612748|              MIA|      28.0| 76| 76|2877.0|765|1354| 0.565| 103| 254|  0.406|403|535| 0.753|  97| 513|610|551|129| 67|226|110|2036|
# |     2544|  2013-14|       00|1610612748|              MIA|      29.0| 77| 77|2902.0|767|1353| 0.567| 116| 306|  0.379|439|585|  0.75|  81| 452|533|488|121| 26|270|126|2089|
# |     2544|  2014-15|       00|1610612739|              CLE|      30.0| 69| 69|2493.0|624|1279| 0.488| 120| 339|  0.354|375|528|  0.71|  51| 365|416|511|109| 49|272|135|1743|
# |     2544|  2015-16|       00|1610612739|              CLE|      31.0| 76| 76|2709.0|737|1416|  0.52|  87| 282|  0.309|359|491| 0.731| 111| 454|565|514|104| 49|249|143|1920|
# |     2544|  2016-17|       00|1610612739|              CLE|      32.0| 74| 74|2795.0|736|1344| 0.548| 124| 342|  0.363|358|531| 0.674|  97| 542|639|646| 92| 44|303|134|1954|
# |     2544|  2017-18|       00|1610612739|              CLE|      33.0| 82| 82|3026.0|857|1580| 0.542| 149| 406|  0.367|388|531| 0.731|  97| 612|709|747|116| 71|347|136|2251|
# |     2544|  2018-19|       00|1610612747|              LAL|      34.0| 55| 55|1937.0|558|1095|  0.51| 111| 327|  0.339|278|418| 0.665|  57| 408|465|454| 72| 33|197| 94|1505|
# |     2544|  2019-20|       00|1610612747|              LAL|      35.0| 67| 67|2316.0|643|1303| 0.493| 148| 425|  0.348|264|381| 0.693|  66| 459|525|684| 78| 36|261|118|1698|
# |     2544|  2020-21|       00|1610612747|              LAL|      36.0| 45| 45|1504.0|422| 823| 0.513| 104| 285|  0.365|178|255| 0.698|  29| 317|346|350| 48| 25|168| 70|1126|
# |     2544|  2021-22|       00|1610612747|              LAL|      37.0| 56| 56|2084.0|640|1221| 0.524| 161| 448|  0.359|254|336| 0.756|  63| 396|459|349| 73| 59|196|121|1695|
# |     2544|  2022-23|       00|1610612747|              LAL|      38.0| 55| 54|1954.0|609|1219|   0.5| 121| 377|  0.321|251|327| 0.768|  65| 392|457|375| 50| 32|178| 88|1590|
# +---------+---------+---------+----------+-----------------+----------+---+---+------+---+----+------+----+----+-------+---+---+------+----+----+---+---+---+---+---+---+----+
# only showing top 20 rows

# %%
sparkDF.printSchema()
# Out:
# root
#  |-- PLAYER_ID: long (nullable = true)
#  |-- SEASON_ID: string (nullable = true)
#  |-- LEAGUE_ID: string (nullable = true)
#  |-- TEAM_ID: long (nullable = true)
#  |-- TEAM_ABBREVIATION: string (nullable = true)
#  |-- PLAYER_AGE: double (nullable = true)
#  |-- GP: long (nullable = true)
#  |-- GS: long (nullable = true)
#  |-- MIN: double (nullable = true)
#  |-- FGM: long (nullable = true)
#  |-- FGA: long (nullable = true)
#  |-- FG_PCT: double (nullable = true)
#  |-- FG3M: long (nullable = true)
#  |-- FG3A: long (nullable = true)
#  |-- FG3_PCT: double (nullable = true)
#  |-- FTM: long (nullable = true)
#  |-- FTA: long (nullable = true)
#  |-- FT_PCT: double (nullable = true)
#  |-- OREB: long (nullable = true)
#  |-- DREB: long (nullable = true)
#  |-- REB: long (nullable = true)
#  |-- AST: long (nullable = true)
#  |-- STL: long (nullable = true)
#  |-- BLK: long (nullable = true)
#  |-- TOV: long (nullable = true)
#  |-- PF: long (nullable = true)
#  |-- PTS: long (nullable = true)

# %%
sparkDF.select(sparkDF['MIN']).show()
# Out:
# +------+
# |   MIN|
# +------+
# |3120.0|
# |3388.0|
# |3361.0|
# |3190.0|
# |3027.0|
# |3054.0|
# |2966.0|
# |3063.0|
# |2326.0|
# |2877.0|
# |2902.0|
# |2493.0|
# |2709.0|
# |2795.0|
# |3026.0|
# |1937.0|
# |2316.0|
# |1504.0|
# |2084.0|
# |1954.0|
# +------+
# only showing top 20 rows

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

# dictionary
games.get_dict()
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2024-03-16 03:06:17.617',
#   'code': 200},
#  'scoreboard': {'gameDate': '2024-03-15',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0022300961',
#     'gameCode': '20240315/PHXCHA',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-15T23:00:00Z',
#     'gameEt': '2024-03-15T19:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612766,
#      'teamName': 'Hornets',
#      'teamCity': 'Charlotte',
#      'teamTricode': 'CHA',
#      'wins': 17,
#      'losses': 50,
#      'score': 96,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 19},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 22},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 29}]},
#     'awayTeam': {'teamId': 1610612756,
#      'teamName': 'Suns',
#      'teamCity': 'Phoenix',
#      'teamTricode': 'PHX',
#      'wins': 39,
#      'losses': 28,
#      'score': 107,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 38},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 15}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1628970,
#       'name': 'Miles Bridges',
#       'jerseyNum': '0',
#       'position': 'F',
#       'teamTricode': 'CHA',
#       'playerSlug': None,
#       'points': 17,
#       'rebounds': 10,
#       'assists': 3},
#      'awayLeaders': {'personId': 1626164,
#       'name': 'Devin Booker',
#       'jerseyNum': '1',
#       'position': 'G',
#       'teamTricode': 'PHX',
#       'playerSlug': None,
#       'points': 21,
#       'rebounds': 6,
#       'assists': 11}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300962',
#     'gameCode': '20240315/MIADET',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-15T23:00:00Z',
#     'gameEt': '2024-03-15T19:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612765,
#      'teamName': 'Pistons',
#      'teamCity': 'Detroit',
#      'teamTricode': 'DET',
#      'wins': 12,
#      'losses': 54,
#      'score': 95,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 18},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 23}]},
#     'awayTeam': {'teamId': 1610612748,
#      'teamName': 'Heat',
#      'teamCity': 'Miami',
#      'teamTricode': 'MIA',
#      'wins': 36,
#      'losses': 30,
#      'score': 108,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 27},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 29},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 24}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1631105,
#       'name': 'Jalen Duren',
#       'jerseyNum': '0',
#       'position': 'C',
#       'teamTricode': 'DET',
#       'playerSlug': None,
#       'points': 15,
#       'rebounds': 17,
#       'assists': 1},
#      'awayLeaders': {'personId': 1628389,
#       'name': 'Bam Adebayo',
#       'jerseyNum': '13',
#       'position': 'C-F',
#       'teamTricode': 'MIA',
#       'playerSlug': None,
#       'points': 22,
#       'rebounds': 9,
#       'assists': 2}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300963',
#     'gameCode': '20240315/ORLTOR',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-15T23:30:00Z',
#     'gameEt': '2024-03-15T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612761,
#      'teamName': 'Raptors',
#      'teamCity': 'Toronto',
#      'teamTricode': 'TOR',
#      'wins': 23,
#      'losses': 44,
#      'score': 103,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 27},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 21},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 25},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 30}]},
#     'awayTeam': {'teamId': 1610612753,
#      'teamName': 'Magic',
#      'teamCity': 'Orlando',
#      'teamTricode': 'ORL',
#      'wins': 39,
#      'losses': 28,
#      'score': 113,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 24},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 29}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1629018,
#       'name': 'Gary Trent Jr.',
#       'jerseyNum': '33',
#       'position': 'G',
#       'teamTricode': 'TOR',
#       'playerSlug': None,
#       'points': 31,
#       'rebounds': 4,
#       'assists': 0},
#      'awayLeaders': {'personId': 1631094,
#       'name': 'Paolo Banchero',
#       'jerseyNum': '5',
#       'position': 'F',
#       'teamTricode': 'ORL',
#       'playerSlug': None,
#       'points': 17,
#       'rebounds': 9,
#       'assists': 8}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300964',
#     'gameCode': '20240315/LACNOP',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-16T00:00:00Z',
#     'gameEt': '2024-03-15T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612740,
#      'teamName': 'Pelicans',
#      'teamCity': 'New Orleans',
#      'teamTricode': 'NOP',
#      'wins': 40,
#      'losses': 26,
#      'score': 112,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 20},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 30},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 32},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 30}]},
#     'awayTeam': {'teamId': 1610612746,
#      'teamName': 'Clippers',
#      'teamCity': 'LA',
#      'teamTricode': 'LAC',
#      'wins': 42,
#      'losses': 24,
#      'score': 104,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 22},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 22},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 36},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 24}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1629627,
#       'name': 'Zion Williamson',
#       'jerseyNum': '1',
#       'position': 'F',
#       'teamTricode': 'NOP',
#       'playerSlug': None,
#       'points': 34,
#       'rebounds': 7,
#       'assists': 4},
#      'awayLeaders': {'personId': 202331,
#       'name': 'Paul George',
#       'jerseyNum': '13',
#       'position': 'F',
#       'teamTricode': 'LAC',
#       'playerSlug': None,
#       'points': 26,
#       'rebounds': 5,
#       'assists': 6}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300965',
#     'gameCode': '20240315/DENSAS',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-16T00:30:00Z',
#     'gameEt': '2024-03-15T20:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612759,
#      'teamName': 'Spurs',
#      'teamCity': 'San Antonio',
#      'teamTricode': 'SAS',
#      'wins': 14,
#      'losses': 53,
#      'score': 106,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 18},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 31},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 30},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 27}]},
#     'awayTeam': {'teamId': 1610612743,
#      'teamName': 'Nuggets',
#      'teamCity': 'Denver',
#      'teamTricode': 'DEN',
#      'wins': 47,
#      'losses': 20,
#      'score': 117,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 37},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 21},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 31}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1631110,
#       'name': 'Jeremy Sochan',
#       'jerseyNum': '10',
#       'position': 'F',
#       'teamTricode': 'SAS',
#       'playerSlug': None,
#       'points': 19,
#       'rebounds': 6,
#       'assists': 4},
#      'awayLeaders': {'personId': 203999,
#       'name': 'Nikola Jokic',
#       'jerseyNum': '15',
#       'position': 'C',
#       'teamTricode': 'DEN',
#       'playerSlug': None,
#       'points': 31,
#       'rebounds': 7,
#       'assists': 5}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300966',
#     'gameCode': '20240315/ATLUTA',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-16T01:30:00Z',
#     'gameEt': '2024-03-15T21:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': '',
#     'gameSubLabel': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612762,
#      'teamName': 'Jazz',
#      'teamCity': 'Utah',
#      'teamTricode': 'UTA',
#      'wins': 29,
#      'losses': 37,
#      'score': 124,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 27},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 37},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 26}]},
#     'awayTeam': {'teamId': 1610612737,
#      'teamName': 'Hawks',
#      'teamCity': 'Atlanta',
#      'teamTricode': 'ATL',
#      'wins': 29,
#      'losses': 37,
#      'score': 122,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 26}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1641718,
#       'name': 'Keyonte George',
#       'jerseyNum': '3',
#       'position': 'G',
#       'teamTricode': 'UTA',
#       'playerSlug': None,
#       'points': 25,
#       'rebounds': 4,
#       'assists': 5},
#      'awayLeaders': {'personId': 1627749,
#       'name': 'Dejounte Murray',
#       'jerseyNum': '5',
#       'position': 'G',
#       'teamTricode': 'ATL',
#       'playerSlug': None,
#       'points': 33,
#       'rebounds': 6,
#       'assists': 9}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]}}
